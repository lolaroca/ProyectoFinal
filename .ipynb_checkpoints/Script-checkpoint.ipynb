# %%
import requests
import plotly.graph_objects as go
import tkinter as tk
from tkinter import ttk
from tkcalendar import Calendar

# %%
# Imprimimos el menú en pantalla
print("""
    Escoja dos sesnores para realizar una comparación de energía
    1) Sensor 1,1     
    2) Sensor 1,2
    """)

# Leemos lo que ingresa el usuario
elijo1=input("-Selecciona sensor 1 :")
elijo2=input("-Selecciona sensor 2: ")


# Según lo que ingresó, código diferente
sensor1=""
sensor2=""
if elijo1=="1":
    sensor1="emjeor"
elif elijo1=="2":
    sensor1="emjeos"
    
if elijo2=="1":
    sensor2="emjeor"
elif elijo2=="2":
    sensor2="emjeos"
# Out:
#     Escoja dos sesnores para realizar una comparación de energía
#     1) Sensor 1,1
#     2) Sensor 1,2
#
# -Selecciona sensor 1 :1
# -Selecciona sensor 2: 2

# %%
import ipywidgets as widgets
from ipywidgets import interact
from datetime import datetime, time

# Función que imprimirá las fechas seleccionadas y sus timestamps
def obtener_fechas(fecha_inicio):
    # Obtener la fecha de fin como el día actual
    fecha_fin = datetime.now().date()
    
    # Convertir fecha_inicio a datetime para calcular el timestamp
    fecha_inicio_datetime = datetime.combine(fecha_inicio, time.min)
    
    timestamp_inicio = (fecha_inicio_datetime - datetime(1970, 1, 1)).total_seconds()
    timestamp_fin = (datetime.combine(fecha_fin, time.min) - datetime(1970, 1, 1)).total_seconds()
    
    print(f"Fechas seleccionadas: {fecha_inicio} - {fecha_fin}")

# Crear widget de fecha de inicio
fecha_inicio_widget = widgets.DatePicker(description='Fecha de inicio', value=datetime(2023, 1, 1).date())

# Crear widget interactivo
interact(obtener_fechas, fecha_inicio=fecha_inicio_widget);
# Out:
# interactive(children=(DatePicker(value=datetime.date(2023, 1, 1), description='Fecha de inicio'), Output()), _…

# %%
url1 = "https://api.energomonitor.com/v1/feeds/emjeic/streams/{0}/data?limit=5000".format(sensor1)
url2 = "https://api.energomonitor.com/v1/feeds/emjeic/streams/{0}/data?limit=5000".format(sensor2)
#url = "https://api.energomonitor.com/v1/feeds/emjeic/streams/emjeov/data?limit=100"
access_token = "p9pbDtQLtXui9OVz8KBoXIdp0916qE"
headers =  {"Content-Type":"application/json", "Authorization": f"Bearer {access_token}"}

result1 = requests.get(url1, headers=headers)
result2 = requests.get(url2, headers=headers)

if (result1.status_code == 200 & result2.status_code == 200):
    response_json1 = result1.json()
    response_json2 = result2.json()
else:
    print(f"Error en la solicitud: {result1.status_code}")

print(result1.status_code)
# Out:
# 200

# %%
import time
datos1 = []
datos2 = []
for i in range(len(response_json1)):
    epoch_time = response_json1[i][0]
    dia = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(epoch_time))
    datos1.append([dia, response_json1[i][1]])

for i in range(len(response_json2)):
    epoch_time = response_json2[i][0]
    dia = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(epoch_time))
    datos2.append([dia, response_json2[i][1]])

# %%
fechas1 = [datos1[i][0] for i in range(len(datos1))]
valores1 = [datos1[i][1] for i in range(len(datos1))]
sensor11 = ["sensor 1,1" for i in range(len(datos1))]
df1 = pd.DataFrame()
df1["fechas"] = fechas1
df1["valores"] = valores1
df1["sensores"]=sensor11

fechas2 = [datos2[i][0] for i in range(len(datos2))]
valores2 = [datos2[i][1] for i in range(len(datos2))]
sensor12 = ["sensor 1,2" for i in range(len(datos2))]
df2 = pd.DataFrame()
df2["fechas"] = fechas2
df2["valores"] = valores2
df2["sensores"]=sensor12

# %%
import plotly.graph_objects as go

# Suponiendo que ya tienes un DataFrame df con columnas "fechas" y "valores"

fig = go.Figure()
fig.add_trace(go.Scatter(x=df1["fechas"], y=df1["valores"], mode='lines', name="Sensor 1,1"))
fig.add_trace(go.Scatter(x=df1["fechas"], y=df2["valores"], mode='lines', name="Sensor 1,2"))

fig.update_layout(title='Comparación dos sensores')

fig.show()
# Out:
# <div>                            <div id="003c24ef-0936-4f3d-a087-83eeb0715524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("003c24ef-0936-4f3d-a087-83eeb0715524")) {                    Plotly.newPlot(                        "003c24ef-0936-4f3d-a087-83eeb0715524",                        [{"mode":"lines","name":"Sensor 1,1","x":["2023-11-06 02:27:00","2023-11-06 02:28:00","2023-11-06 02:29:00","2023-11-06 02:30:00","2023-11-06 02:31:00","2023-11-06 02:32:00","2023-11-06 02:33:00","2023-11-06 02:34:00","2023-11-06 02:35:00","2023-11-06 02:36:00","2023-11-06 02:37:00","2023-11-06 02:38:00","2023-11-06 02:39:00","2023-11-06 02:40:00","2023-11-06 02:41:00","2023-11-06 02:42:00","2023-11-06 02:43:00","2023-11-06 02:44:00","2023-11-06 02:45:00","2023-11-06 02:46:00","2023-11-06 02:47:00","2023-11-06 02:48:00","2023-11-06 02:49:00","2023-11-06 02:50:00","2023-11-06 02:51:00","2023-11-06 02:52:00","2023-11-06 02:53:00","2023-11-06 02:54:00","2023-11-06 02:55:00","2023-11-06 02:56:00","2023-11-06 02:57:00","2023-11-06 02:58:00","2023-11-06 02:59:00","2023-11-06 03:00:00","2023-11-06 03:01:00","2023-11-06 03:02:00","2023-11-06 03:03:00","2023-11-06 03:04:00","2023-11-06 03:05:00","2023-11-06 03:06:00","2023-11-06 03:07:00","2023-11-06 03:08:00","2023-11-06 03:09:00","2023-11-06 03:10:00","2023-11-06 03:11:00","2023-11-06 03:12:00","2023-11-06 03:13:00","2023-11-06 03:14:00","2023-11-06 03:15:00","2023-11-06 03:16:00","2023-11-06 03:17:00","2023-11-06 03:18:00","2023-11-06 03:19:00","2023-11-06 03:20:00","2023-11-06 03:21:00","2023-11-06 03:22:00","2023-11-06 03:23:00","2023-11-06 03:24:00","2023-11-06 03:25:00","2023-11-06 03:26:00","2023-11-06 03:27:00","2023-11-06 03:28:00","2023-11-06 03:29:00","2023-11-06 03:30:00","2023-11-06 03:31:00","2023-11-06 03:32:00","2023-11-06 03:33:00","2023-11-06 03:34:00","2023-11-06 03:35:00","2023-11-06 03:36:00","2023-11-06 03:37:00","2023-11-06 03:38:00","2023-11-06 03:39:00","2023-11-06 03:40:00","2023-11-06 03:41:00","2023-11-06 03:42:00","2023-11-06 03:43:00","2023-11-06 03:44:00","2023-11-06 03:45:00","2023-11-06 03:46:00","2023-11-06 03:47:00","2023-11-06 03:48:00","2023-11-06 03:49:00","2023-11-06 03:50:00","2023-11-06 03:51:00","2023-11-06 03:52:00","2023-11-06 03:53:00","2023-11-06 03:54:00","2023-11-06 03:55:00","2023-11-06 03:56:00","2023-11-06 03:57:00","2023-11-06 03:58:00","2023-11-06 03:59:00","2023-11-06 04:00:00","2023-11-06 04:01:00","2023-11-06 04:02:00","2023-11-06 04:03:00","2023-11-06 04:04:00","2023-11-06 04:05:00","2023-11-06 04:06:00","2023-11-06 04:07:00","2023-11-06 04:08:00","2023-11-06 04:09:00","2023-11-06 04:10:00","2023-11-06 04:11:00","2023-11-06 04:12:00","2023-11-06 04:13:00","2023-11-06 04:14:00","2023-11-06 04:15:00","2023-11-06 04:16:00","2023-11-06 04:17:00","2023-11-06 04:18:00","2023-11-06 04:19:00","2023-11-06 04:20:00","2023-11-06 04:21:00","2023-11-06 04:22:00","2023-11-06 04:23:00","2023-11-06 04:24:00","2023-11-06 04:25:00","2023-11-06 04:26:00","2023-11-06 04:27:00","2023-11-06 04:28:00","2023-11-06 04:29:00","2023-11-06 04:30:00","2023-11-06 04:31:00","2023-11-06 04:32:00","2023-11-06 04:33:00","2023-11-06 04:34:00","2023-11-06 04:35:00","2023-11-06 04:36:00","2023-11-06 04:37:00","2023-11-06 04:38:00","2023-11-06 04:39:00","2023-11-06 04:40:00","2023-11-06 04:41:00","2023-11-06 04:42:00","2023-11-06 04:43:00","2023-11-06 04:44:00","2023-11-06 04:45:00","2023-11-06 04:46:00","2023-11-06 04:47:00","2023-11-06 04:48:00","2023-11-06 04:49:00","2023-11-06 04:50:00","2023-11-06 04:51:00","2023-11-06 04:52:00","2023-11-06 04:53:00","2023-11-06 04:54:00","2023-11-06 04:55:00","2023-11-06 04:56:00","2023-11-06 04:57:00","2023-11-06 04:58:00","2023-11-06 04:59:00","2023-11-06 05:00:00","2023-11-06 05:01:00","2023-11-06 05:02: ...
